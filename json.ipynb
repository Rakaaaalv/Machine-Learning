# %%
import json

nb = json.load(open("Source_Code.ipynb", "r", encoding="utf-8"))

if "widgets" in nb.get("metadata", {}):
    del nb["metadata"]["widgets"]

json.dump(nb, open("Source_Code.ipynb", "w", encoding="utf-8"), ensure_ascii=False, indent=2)
